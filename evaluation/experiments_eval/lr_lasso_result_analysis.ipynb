# %%
import os
import json
import pandas as pdo
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from typing import Dict, List, Any, Optional, Tuple
import scanpy as sc
import pickle
import sys

# Ensure the parent directory is in the system path
sys.path.append('/home/minhang/mds_project/sc_classification')
from utils.experiment_manager import ExperimentManager
from utils.experiment_analysis import ExperimentAnalyzer

# surpress warnings
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/minhang/miniconda3/envs/mds_responder_analysis/lib/python3.11/site-packages/anndata/utils.py:434: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
experiment_id = "20250714_205422_fa_100_random_6dbbde08"
experiments_dir = '/home/minhang/mds_project/sc_classification/experiments/'

experiment_manager = ExperimentManager(experiments_dir)
analyzer = ExperimentAnalyzer(experiment_manager)

# %%
try:
    experiment = experiment_manager.load_experiment(experiment_id)
    print(f"Loaded experiment: {experiment_id}")
    print(f'DR method: {experiment.config.get("dimension_reduction.method")}')
    print(f'N components: {experiment.config.get("dimension_reduction.n_components")}')
    print(f'Downsampling method: {experiment.config.get("downsampling.method")}')
    print(f'Downsampling rate: {experiment.config.get("downsampling.rate")}')
    print(f'Downsampling seed: {experiment.config.get("downsampling.seed")}')
    print(f'Downsampling random state: {experiment.config.get("downsampling.random_state")}')
    print(f'Downsampling n_jobs: {experiment.config.get("downsampling.n_jobs")}')
except Exception as e:
    print(f"Error loading experiment {experiment_id}: {e}")
    sys.exit(1)
# Out:
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loaded experiment: 20250714_205422_fa_100_random_6dbbde08
# DR method: fa
# N components: 100
# Downsampling method: random
# Downsampling rate: None
# Downsampling seed: None
# Downsampling random state: None
# Downsampling n_jobs: None

# %% [markdown]
# ### Generate unsupervised diagnosis plots (factor sum of square loading and gene communality)

# %%
analyzer.generate_unsupervised_fa_report(experiment_id=experiment_id)
# Out:
# --- Generating Unsupervised FA Report for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved SS Loadings plot to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/ss_loadings_per_factor.png
# Saved Communality plot to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/gene_communality_distribution.png

# %%
# create a list of factors to compare [X_fa_1, X_fa_2, ..., X_fa_100]
factors_to_compare = [f'X_fa_{i}' for i in range(1, 101)]
print("\n--- EDA: Comparing Factor Loading Distributions ---")
analyzer.plot_factor_loading_distributions(
    experiment_id=experiment_id,
    factors_to_compare=factors_to_compare
)
# Out:
# --- EDA: Comparing Factor Loading Distributions ---
# --- Plotting Factor Loading Distributions for 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved factor loading distribution plot to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/factor_loading_distributions.png

# %% [markdown]
# #### Try to understand if gseapy prerank is scale invariant

# %%
# Pick a low-variance factor to inspect
factor_to_debug = 'X_fa_69'

# === Run GSEA on ORIGINAL Loadings with debug ===
print("\nRUNNING GSEA ON ORIGINAL (WITH DEBUG)")
analyzer.run_gsea_on_factors(
    experiment_id=experiment_id,
    rescale_loadings=False,
    debug_factor=factor_to_debug
)

# === Run GSEA on RESCALED Loadings with debug ===
print("\nRUNNING GSEA ON RESCALED (WITH DEBUG)")
analyzer.run_gsea_on_factors(
    experiment_id=experiment_id,
    rescale_loadings=True,
    debug_factor=factor_to_debug
)
# Out:
# RUNNING GSEA ON ORIGINAL (WITH DEBUG)
# --- Running GSEA on All Factors (Original Loadings) for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   >>>> DEBUG: Saved ranked list for X_fa_69 to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_factors_original/DEBUG_RANKED_LIST_X_fa_69_Original.csv
#   Running GSEA on factor: X_fa_1
#   Running GSEA on factor: X_fa_2
#   Running GSEA on factor: X_fa_3
#   Running GSEA on factor: X_fa_4
#   Running GSEA on factor: X_fa_5
#   Running GSEA on factor: X_fa_6
#   Running GSEA on factor: X_fa_7
#   Running GSEA on factor: X_fa_8
#   Running GSEA on factor: X_fa_9
#   Running GSEA on factor: X_fa_10
#   Running GSEA on factor: X_fa_11
#   Running GSEA on factor: X_fa_12
#   Running GSEA on factor: X_fa_13
#   Running GSEA on factor: X_fa_14
#   Running GSEA on factor: X_fa_15
#   Running GSEA on factor: X_fa_16
#   Running GSEA on factor: X_fa_17
#   Running GSEA on factor: X_fa_18
#   Running GSEA on factor: X_fa_19
#   Running GSEA on factor: X_fa_20
#   Running GSEA on factor: X_fa_21
#   Running GSEA on factor: X_fa_22
#   Running GSEA on factor: X_fa_23
#   Running GSEA on factor: X_fa_24
#   Running GSEA on factor: X_fa_25
#   Running GSEA on factor: X_fa_26
#   Running GSEA on factor: X_fa_27
#   Running GSEA on factor: X_fa_28
#   Running GSEA on factor: X_fa_29
#   Running GSEA on factor: X_fa_30
#   Running GSEA on factor: X_fa_31
#   Running GSEA on factor: X_fa_32
#   Running GSEA on factor: X_fa_33
#   Running GSEA on factor: X_fa_34
#   Running GSEA on factor: X_fa_35
#   Running GSEA on factor: X_fa_36
#   Running GSEA on factor: X_fa_37
#   Running GSEA on factor: X_fa_38
#   Running GSEA on factor: X_fa_39
#   Running GSEA on factor: X_fa_40
#   Running GSEA on factor: X_fa_41
#   Running GSEA on factor: X_fa_42
#   Running GSEA on factor: X_fa_43
#   Running GSEA on factor: X_fa_44
#   Running GSEA on factor: X_fa_45
#   Running GSEA on factor: X_fa_46
#   Running GSEA on factor: X_fa_47
#   Running GSEA on factor: X_fa_48
#   Running GSEA on factor: X_fa_49
#   Running GSEA on factor: X_fa_50
#   Running GSEA on factor: X_fa_51
#   Running GSEA on factor: X_fa_52
#   Running GSEA on factor: X_fa_53
#   Running GSEA on factor: X_fa_54
#   Running GSEA on factor: X_fa_55
#   Running GSEA on factor: X_fa_56
#   Running GSEA on factor: X_fa_57
#   Running GSEA on factor: X_fa_58
#   Running GSEA on factor: X_fa_59
#   Running GSEA on factor: X_fa_60
#   Running GSEA on factor: X_fa_61
#   Running GSEA on factor: X_fa_62
#   Running GSEA on factor: X_fa_63
#   Running GSEA on factor: X_fa_64
#   Running GSEA on factor: X_fa_65
#   Running GSEA on factor: X_fa_66
#   Running GSEA on factor: X_fa_67
#   Running GSEA on factor: X_fa_68
#   Running GSEA on factor: X_fa_69
#   Running GSEA on factor: X_fa_70
#   Running GSEA on factor: X_fa_71
#   Running GSEA on factor: X_fa_72
#   Running GSEA on factor: X_fa_73
#   Running GSEA on factor: X_fa_74
#   Running GSEA on factor: X_fa_75
#   Running GSEA on factor: X_fa_76
#   Running GSEA on factor: X_fa_77
#   Running GSEA on factor: X_fa_78
#   Running GSEA on factor: X_fa_79
#   Running GSEA on factor: X_fa_80
#   Running GSEA on factor: X_fa_81
#   Running GSEA on factor: X_fa_82
#   Running GSEA on factor: X_fa_83
#   Running GSEA on factor: X_fa_84
#   Running GSEA on factor: X_fa_85
#   Running GSEA on factor: X_fa_86
#   Running GSEA on factor: X_fa_87
#   Running GSEA on factor: X_fa_88
#   Running GSEA on factor: X_fa_89
#   Running GSEA on factor: X_fa_90
#   Running GSEA on factor: X_fa_91
#   Running GSEA on factor: X_fa_92
#   Running GSEA on factor: X_fa_93
#   Running GSEA on factor: X_fa_94
#   Running GSEA on factor: X_fa_95
#   Running GSEA on factor: X_fa_96
#   Running GSEA on factor: X_fa_97
#   Running GSEA on factor: X_fa_98
#   Running GSEA on factor: X_fa_99
#   Running GSEA on factor: X_fa_100
#
# Generated summary plot of significant hits: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_factors_original/summary_significant_hits_original.png
#
# RUNNING GSEA ON RESCALED (WITH DEBUG)
# --- Running GSEA on All Factors (Rescaled Loadings) for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Rescaling factor loadings to common [-1, 1] scale...
#   >>>> DEBUG: Saved ranked list for X_fa_69 to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_factors_rescaled/DEBUG_RANKED_LIST_X_fa_69_Rescaled.csv
#   Running GSEA on factor: X_fa_1
#   Running GSEA on factor: X_fa_2
#   Running GSEA on factor: X_fa_3
#   Running GSEA on factor: X_fa_4
#   Running GSEA on factor: X_fa_5
#   Running GSEA on factor: X_fa_6
#   Running GSEA on factor: X_fa_7
#   Running GSEA on factor: X_fa_8
#   Running GSEA on factor: X_fa_9
#   Running GSEA on factor: X_fa_10
#   Running GSEA on factor: X_fa_11
#   Running GSEA on factor: X_fa_12
#   Running GSEA on factor: X_fa_13
#   Running GSEA on factor: X_fa_14
#   Running GSEA on factor: X_fa_15
#   Running GSEA on factor: X_fa_16
#   Running GSEA on factor: X_fa_17
#   Running GSEA on factor: X_fa_18
#   Running GSEA on factor: X_fa_19
#   Running GSEA on factor: X_fa_20
#   Running GSEA on factor: X_fa_21
#   Running GSEA on factor: X_fa_22
#   Running GSEA on factor: X_fa_23
#   Running GSEA on factor: X_fa_24
#   Running GSEA on factor: X_fa_25
#   Running GSEA on factor: X_fa_26
#   Running GSEA on factor: X_fa_27
#   Running GSEA on factor: X_fa_28
#   Running GSEA on factor: X_fa_29
#   Running GSEA on factor: X_fa_30
#   Running GSEA on factor: X_fa_31
#   Running GSEA on factor: X_fa_32
#   Running GSEA on factor: X_fa_33
#   Running GSEA on factor: X_fa_34
#   Running GSEA on factor: X_fa_35
#   Running GSEA on factor: X_fa_36
#   Running GSEA on factor: X_fa_37
#   Running GSEA on factor: X_fa_38
#   Running GSEA on factor: X_fa_39
#   Running GSEA on factor: X_fa_40
#   Running GSEA on factor: X_fa_41
#   Running GSEA on factor: X_fa_42
#   Running GSEA on factor: X_fa_43
#   Running GSEA on factor: X_fa_44
#   Running GSEA on factor: X_fa_45
#   Running GSEA on factor: X_fa_46
#   Running GSEA on factor: X_fa_47
#   Running GSEA on factor: X_fa_48
#   Running GSEA on factor: X_fa_49
#   Running GSEA on factor: X_fa_50
#   Running GSEA on factor: X_fa_51
#   Running GSEA on factor: X_fa_52
#   Running GSEA on factor: X_fa_53
#   Running GSEA on factor: X_fa_54
#   Running GSEA on factor: X_fa_55
#   Running GSEA on factor: X_fa_56
#   Running GSEA on factor: X_fa_57
#   Running GSEA on factor: X_fa_58
#   Running GSEA on factor: X_fa_59
#   Running GSEA on factor: X_fa_60
#   Running GSEA on factor: X_fa_61
#   Running GSEA on factor: X_fa_62
#   Running GSEA on factor: X_fa_63
#   Running GSEA on factor: X_fa_64
#   Running GSEA on factor: X_fa_65
#   Running GSEA on factor: X_fa_66
#   Running GSEA on factor: X_fa_67
#   Running GSEA on factor: X_fa_68
#   Running GSEA on factor: X_fa_69
#   Running GSEA on factor: X_fa_70
#   Running GSEA on factor: X_fa_71
#   Running GSEA on factor: X_fa_72
#   Running GSEA on factor: X_fa_73
#   Running GSEA on factor: X_fa_74
#   Running GSEA on factor: X_fa_75
#   Running GSEA on factor: X_fa_76
#   Running GSEA on factor: X_fa_77
#   Running GSEA on factor: X_fa_78
#   Running GSEA on factor: X_fa_79
#   Running GSEA on factor: X_fa_80
#   Running GSEA on factor: X_fa_81
#   Running GSEA on factor: X_fa_82
#   Running GSEA on factor: X_fa_83
#   Running GSEA on factor: X_fa_84
#   Running GSEA on factor: X_fa_85
#   Running GSEA on factor: X_fa_86
#   Running GSEA on factor: X_fa_87
#   Running GSEA on factor: X_fa_88
#   Running GSEA on factor: X_fa_89
#   Running GSEA on factor: X_fa_90
#   Running GSEA on factor: X_fa_91
#   Running GSEA on factor: X_fa_92
#   Running GSEA on factor: X_fa_93
#   Running GSEA on factor: X_fa_94
#   Running GSEA on factor: X_fa_95
#   Running GSEA on factor: X_fa_96
#   Running GSEA on factor: X_fa_97
#   Running GSEA on factor: X_fa_98
#   Running GSEA on factor: X_fa_99
#   Running GSEA on factor: X_fa_100
#
# Generated summary plot of significant hits: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_factors_rescaled/summary_significant_hits_rescaled.png

# %% [markdown]
# ### GSEA on all factors (Rescaled V.S. non-rescaled)

# %%
print("\n" + "="*80)
print("RUNNING GSEA ON ORIGINAL, UN-RESCALED FACTOR LOADINGS")
print("="*80)
analyzer.run_gsea_on_factors(
    experiment_id=experiment_id,
    rescale_loadings=False  # This is the default, baseline strategy
)

# === Run GSEA on RESCALED Loadings ===
print("\n" + "="*80)
print("RUNNING GSEA ON RESCALED FACTOR LOADINGS")
print("="*80)
analyzer.run_gsea_on_factors(
    experiment_id=experiment_id,
    rescale_loadings=True   # This activates the new, rescaled strategy
)

print("\nComparison analysis complete.")
# Out:
# ================================================================================
# RUNNING GSEA ON ORIGINAL, UN-RESCALED FACTOR LOADINGS
# ================================================================================
# --- Running GSEA on All Factors (Original Loadings) for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_1
#   Running GSEA on factor: X_fa_2
#   Running GSEA on factor: X_fa_3
#   Running GSEA on factor: X_fa_4
#   Running GSEA on factor: X_fa_5
#   Running GSEA on factor: X_fa_6
#   Running GSEA on factor: X_fa_7
#   Running GSEA on factor: X_fa_8
#   Running GSEA on factor: X_fa_9
#   Running GSEA on factor: X_fa_10
#   Running GSEA on factor: X_fa_11
#   Running GSEA on factor: X_fa_12
#   Running GSEA on factor: X_fa_13
#   Running GSEA on factor: X_fa_14
#   Running GSEA on factor: X_fa_15
#   Running GSEA on factor: X_fa_16
#   Running GSEA on factor: X_fa_17
#   Running GSEA on factor: X_fa_18
#   Running GSEA on factor: X_fa_19
#   Running GSEA on factor: X_fa_20
#   Running GSEA on factor: X_fa_21
#   Running GSEA on factor: X_fa_22
#   Running GSEA on factor: X_fa_23
#   Running GSEA on factor: X_fa_24
#   Running GSEA on factor: X_fa_25
#   Running GSEA on factor: X_fa_26
#   Running GSEA on factor: X_fa_27
#   Running GSEA on factor: X_fa_28
#   Running GSEA on factor: X_fa_29
#   Running GSEA on factor: X_fa_30
#   Running GSEA on factor: X_fa_31
#   Running GSEA on factor: X_fa_32
#   Running GSEA on factor: X_fa_33
#   Running GSEA on factor: X_fa_34
#   Running GSEA on factor: X_fa_35
#   Running GSEA on factor: X_fa_36
#   Running GSEA on factor: X_fa_37
#   Running GSEA on factor: X_fa_38
#   Running GSEA on factor: X_fa_39
#   Running GSEA on factor: X_fa_40
#   Running GSEA on factor: X_fa_41
#   Running GSEA on factor: X_fa_42
#   Running GSEA on factor: X_fa_43
#   Running GSEA on factor: X_fa_44
#   Running GSEA on factor: X_fa_45
#   Running GSEA on factor: X_fa_46
#   Running GSEA on factor: X_fa_47
#   Running GSEA on factor: X_fa_48
#   Running GSEA on factor: X_fa_49
#   Running GSEA on factor: X_fa_50
#   Running GSEA on factor: X_fa_51
#   Running GSEA on factor: X_fa_52
#   Running GSEA on factor: X_fa_53
#   Running GSEA on factor: X_fa_54
#   Running GSEA on factor: X_fa_55
#   Running GSEA on factor: X_fa_56
#   Running GSEA on factor: X_fa_57
#   Running GSEA on factor: X_fa_58
#   Running GSEA on factor: X_fa_59
#   Running GSEA on factor: X_fa_60
#   Running GSEA on factor: X_fa_61
#   Running GSEA on factor: X_fa_62
#   Running GSEA on factor: X_fa_63
#   Running GSEA on factor: X_fa_64
#   Running GSEA on factor: X_fa_65
#   Running GSEA on factor: X_fa_66
#   Running GSEA on factor: X_fa_67
#   Running GSEA on factor: X_fa_68
#   Running GSEA on factor: X_fa_69
#   Running GSEA on factor: X_fa_70
#   Running GSEA on factor: X_fa_71
#   Running GSEA on factor: X_fa_72
#   Running GSEA on factor: X_fa_73
#   Running GSEA on factor: X_fa_74
#   Running GSEA on factor: X_fa_75
#   Running GSEA on factor: X_fa_76
#   Running GSEA on factor: X_fa_77
#   Running GSEA on factor: X_fa_78
#   Running GSEA on factor: X_fa_79
#   Running GSEA on factor: X_fa_80
#   Running GSEA on factor: X_fa_81
#   Running GSEA on factor: X_fa_82
#   Running GSEA on factor: X_fa_83
#   Running GSEA on factor: X_fa_84
#   Running GSEA on factor: X_fa_85
#   Running GSEA on factor: X_fa_86
#   Running GSEA on factor: X_fa_87
#   Running GSEA on factor: X_fa_88
#   Running GSEA on factor: X_fa_89
#   Running GSEA on factor: X_fa_90
#   Running GSEA on factor: X_fa_91
#   Running GSEA on factor: X_fa_92
#   Running GSEA on factor: X_fa_93
#   Running GSEA on factor: X_fa_94
#   Running GSEA on factor: X_fa_95
#   Running GSEA on factor: X_fa_96
#   Running GSEA on factor: X_fa_97
#   Running GSEA on factor: X_fa_98
#   Running GSEA on factor: X_fa_99
#   Running GSEA on factor: X_fa_100
#
# Generated summary plot of significant hits: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_factors_original/summary_significant_hits_original.png
#
# ================================================================================
# RUNNING GSEA ON RESCALED FACTOR LOADINGS
# ================================================================================
# --- Running GSEA on All Factors (Rescaled Loadings) for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Rescaling factor loadings to common [-1, 1] scale...
#   Running GSEA on factor: X_fa_1
#   Running GSEA on factor: X_fa_2
#   Running GSEA on factor: X_fa_3
#   Running GSEA on factor: X_fa_4
#   Running GSEA on factor: X_fa_5
#   Running GSEA on factor: X_fa_6
#   Running GSEA on factor: X_fa_7
#   Running GSEA on factor: X_fa_8
#   Running GSEA on factor: X_fa_9
#   Running GSEA on factor: X_fa_10
#   Running GSEA on factor: X_fa_11
#   Running GSEA on factor: X_fa_12
#   Running GSEA on factor: X_fa_13
#   Running GSEA on factor: X_fa_14
#   Running GSEA on factor: X_fa_15
#   Running GSEA on factor: X_fa_16
#   Running GSEA on factor: X_fa_17
#   Running GSEA on factor: X_fa_18
#   Running GSEA on factor: X_fa_19
#   Running GSEA on factor: X_fa_20
#   Running GSEA on factor: X_fa_21
#   Running GSEA on factor: X_fa_22
#   Running GSEA on factor: X_fa_23
#   Running GSEA on factor: X_fa_24
#   Running GSEA on factor: X_fa_25
#   Running GSEA on factor: X_fa_26
#   Running GSEA on factor: X_fa_27
#   Running GSEA on factor: X_fa_28
#   Running GSEA on factor: X_fa_29
#   Running GSEA on factor: X_fa_30
#   Running GSEA on factor: X_fa_31
#   Running GSEA on factor: X_fa_32
#   Running GSEA on factor: X_fa_33
#   Running GSEA on factor: X_fa_34
#   Running GSEA on factor: X_fa_35
#   Running GSEA on factor: X_fa_36
#   Running GSEA on factor: X_fa_37
#   Running GSEA on factor: X_fa_38
#   Running GSEA on factor: X_fa_39
#   Running GSEA on factor: X_fa_40
#   Running GSEA on factor: X_fa_41
#   Running GSEA on factor: X_fa_42
#   Running GSEA on factor: X_fa_43
#   Running GSEA on factor: X_fa_44
#   Running GSEA on factor: X_fa_45
#   Running GSEA on factor: X_fa_46
#   Running GSEA on factor: X_fa_47
#   Running GSEA on factor: X_fa_48
#   Running GSEA on factor: X_fa_49
#   Running GSEA on factor: X_fa_50
#   Running GSEA on factor: X_fa_51
#   Running GSEA on factor: X_fa_52
#   Running GSEA on factor: X_fa_53
#   Running GSEA on factor: X_fa_54
#   Running GSEA on factor: X_fa_55
#   Running GSEA on factor: X_fa_56
#   Running GSEA on factor: X_fa_57
#   Running GSEA on factor: X_fa_58
#   Running GSEA on factor: X_fa_59
#   Running GSEA on factor: X_fa_60
#   Running GSEA on factor: X_fa_61
#   Running GSEA on factor: X_fa_62
#   Running GSEA on factor: X_fa_63
#   Running GSEA on factor: X_fa_64
#   Running GSEA on factor: X_fa_65
#   Running GSEA on factor: X_fa_66
#   Running GSEA on factor: X_fa_67
#   Running GSEA on factor: X_fa_68
#   Running GSEA on factor: X_fa_69
#   Running GSEA on factor: X_fa_70
#   Running GSEA on factor: X_fa_71
#   Running GSEA on factor: X_fa_72
#   Running GSEA on factor: X_fa_73
#   Running GSEA on factor: X_fa_74
#   Running GSEA on factor: X_fa_75
#   Running GSEA on factor: X_fa_76
#   Running GSEA on factor: X_fa_77
#   Running GSEA on factor: X_fa_78
#   Running GSEA on factor: X_fa_79
#   Running GSEA on factor: X_fa_80
#   Running GSEA on factor: X_fa_81
#   Running GSEA on factor: X_fa_82
#   Running GSEA on factor: X_fa_83
#   Running GSEA on factor: X_fa_84
#   Running GSEA on factor: X_fa_85
#   Running GSEA on factor: X_fa_86
#   Running GSEA on factor: X_fa_87
#   Running GSEA on factor: X_fa_88
#   Running GSEA on factor: X_fa_89
#   Running GSEA on factor: X_fa_90
#   Running GSEA on factor: X_fa_91
#   Running GSEA on factor: X_fa_92
#   Running GSEA on factor: X_fa_93
#   Running GSEA on factor: X_fa_94
#   Running GSEA on factor: X_fa_95
#   Running GSEA on factor: X_fa_96
#   Running GSEA on factor: X_fa_97
#   Running GSEA on factor: X_fa_98
#   Running GSEA on factor: X_fa_99
#   Running GSEA on factor: X_fa_100
#
# Generated summary plot of significant hits: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_factors_rescaled/summary_significant_hits_rescaled.png
#
# Comparison analysis complete.

# %%
# --- 1. Identify Top 10 Factors ---
print("Identifying top 10 factors based on Sum of Squared Loadings...")

# Load the transformed data to get the factor loadings
exp = experiment_manager.load_experiment(experiment_id)
dr_method = exp.config.get('dimension_reduction.method')
n_components = exp.config.get('dimension_reduction.n_components')
transformed_adata = sc.read_h5ad(exp.get_path('transformed_data', dr_method=dr_method, n_components=n_components))

loadings = transformed_adata.varm['FA_loadings']
loading_df = pd.DataFrame(loadings, index=transformed_adata.var_names, 
                          columns=[f'X_fa_{i+1}' for i in range(loadings.shape[1])])

# Calculate SS Loadings and get the top 10
ss_loadings = (loading_df ** 2).sum(axis=0).sort_values(ascending=False)
top_10_factors = ss_loadings.head(10).index.tolist()

print(f"Top 10 factors identified: {top_10_factors}")
# Out:
# Identifying top 10 factors based on Sum of Squared Loadings...
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Top 10 factors identified: ['X_fa_1', 'X_fa_2', 'X_fa_3', 'X_fa_5', 'X_fa_4', 'X_fa_6', 'X_fa_7', 'X_fa_8', 'X_fa_9', 'X_fa_10']

# %%
print("\n--- Running GSEA on Top 10 Factors ---")

# We will use the default Hallmark gene sets path you provided.
# You can override this by passing the gene_sets_path argument.
analyzer.run_gsea_on_factors(
    experiment_id=experiment_id,
    factor_names=top_10_factors
)

gsea_output_dir = exp.experiment_dir / "analysis" / "gsea_on_factors"
print(f"\nCompleted GSEA analysis.")
print(f"Results are saved in subdirectories within:\n{gsea_output_dir}")
# Out:
# --- Running GSEA on Top 10 Factors ---
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_1
#     Successfully ran GSEA for X_fa_1. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_1
#   Running GSEA on factor: X_fa_2
#     Successfully ran GSEA for X_fa_2. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_2
#   Running GSEA on factor: X_fa_3
#     Successfully ran GSEA for X_fa_3. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_3
#   Running GSEA on factor: X_fa_5
#     Successfully ran GSEA for X_fa_5. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_5
#   Running GSEA on factor: X_fa_4
#     Successfully ran GSEA for X_fa_4. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_4
#   Running GSEA on factor: X_fa_6
#     Successfully ran GSEA for X_fa_6. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_6
#   Running GSEA on factor: X_fa_7
#     Successfully ran GSEA for X_fa_7. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_7
#   Running GSEA on factor: X_fa_8
#     Successfully ran GSEA for X_fa_8. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_8
#   Running GSEA on factor: X_fa_9
#     Successfully ran GSEA for X_fa_9. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_9
#   Running GSEA on factor: X_fa_10
#     Successfully ran GSEA for X_fa_10. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_10
#
# Completed GSEA analysis.
# Results are saved in subdirectories within:
# /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/gsea_on_factors

# %% [markdown]
# ### ORA and exploratory analysis on gene communality

# %%
# --- Calculate Communalities ---
# We can reuse the 'loading_df' from the previous cell
communalities = (loading_df ** 2).sum(axis=1).sort_values(ascending=False)

# Get top 100 best-explained genes
top_100_genes = communalities.head(100)

# Get bottom 100 worst-explained genes
bottom_100_genes = communalities.tail(100).sort_values(ascending=True)

# --- Display Results ---
print("--- Top 100 Genes (Best Explained by the FA Model) ---")
print(top_100_genes)
print("\n" + "="*50 + "\n")
print("--- Bottom 100 Genes (Worst Explained by the FA Model) ---")
print(bottom_100_genes)
# Out:
# --- Top 100 Genes (Best Explained by the FA Model) ---
# RUNX2      0.997186
# RTL8C      0.996426
# RTL1       0.996293
# S100A13    0.996238
# RTKN       0.996097
#              ...
# ONECUT3    0.990045
# S100B      0.989970
# ATP5F1D    0.989960
# SPEF1      0.989959
# NHSL1      0.989955
# Length: 100, dtype: float64
#
# ==================================================
#
# --- Bottom 100 Genes (Worst Explained by the FA Model) ---
# IGLV1-50      0.171423
# HFE           0.303391
# TRBJ1-4       0.329189
# HEYL          0.382181
# NPIPB13       0.388604
#                 ...
# KCNMA1-AS3    0.842713
# TMEM270       0.842767
# CRIP1         0.843929
# COL23A1       0.844667
# AC012447.1    0.844693
# Length: 100, dtype: float64

# %%
analyzer.analyze_communality_extremes(experiment_id=experiment_id, n_genes=100)
# Out:
# --- Analyzing Communality Extremes for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved communality bar plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/top_bottom_communality_genes.png
#
# Running Over-Representation Analysis (ORA)...
#   Saved ORA results for Top 100 genes to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/ORA_results_Top_100_genes.csv
#   Saved ORA results for Bottom 100 genes to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/ORA_results_Bottom_100_genes.csv

# %%
analyzer.analyze_communality_extremes(experiment_id=experiment_id, n_genes=100)
exp = experiment_manager.load_experiment(experiment_id)

# Now, plot the results from the generated CSVs
unsupervised_dir = exp.experiment_dir / "analysis" / "unsupervised_dr_analysis"

# Plot for Top 100 Genes
top_genes_csv = unsupervised_dir / "ORA_results_Top_100_genes.csv"
top_genes_plot = unsupervised_dir / "ORA_plot_Top_100_genes.png"
if top_genes_csv.exists():
    analyzer.plot_ora_results(top_genes_csv, top_genes_plot)

# Plot for Bottom 100 Genes
bottom_genes_csv = unsupervised_dir / "ORA_results_Bottom_100_genes.csv"
bottom_genes_plot = unsupervised_dir / "ORA_plot_Bottom_100_genes.png"
if bottom_genes_csv.exists():
    analyzer.plot_ora_results(bottom_genes_csv, bottom_genes_plot)
# Out:
# --- Analyzing Communality Extremes for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved communality bar plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/top_bottom_communality_genes.png
#
# Running Over-Representation Analysis (ORA)...
#   Saved ORA results for Top 100 genes to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/ORA_results_Top_100_genes.csv
#   Saved ORA results for Bottom 100 genes to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/ORA_results_Bottom_100_genes.csv
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   - Saved ORA plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/ORA_plot_Top_100_genes.png
#   - No significant terms found at p < 0.05 in ORA_results_Bottom_100_genes.csv

# %% [markdown]
# ## Generate 2-panels report per patient

# %%
print("Running LR-Lasso analysis...")
analyzer.generate_lasso_path_2panels_report(experiment_id)  
print("LR-Lasso analysis complete!")

# Check what was created
summary_plots_dir = experiment.get_path('summary_plots')
print(f"\nResults saved to: {summary_plots_dir}")
if summary_plots_dir.exists():
    print("Files created:")
    for file in summary_plots_dir.glob("*.png"):
        print(f"  - {file.name}")
# Out:
# Running LR-Lasso analysis...
# --- Generating Standard Analysis Report for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Generating plot for patient: P01
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P01_metrics_and_coefficients.png
# Generating plot for patient: P02
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P02_metrics_and_coefficients.png
# Generating plot for patient: P03
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P03_metrics_and_coefficients.png
# Generating plot for patient: P04
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P04_metrics_and_coefficients.png
# Generating plot for patient: P05
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P05_metrics_and_coefficients.png
# Generating plot for patient: P06
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P06_metrics_and_coefficients.png
# Generating plot for patient: P07
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P07_metrics_and_coefficients.png
# Generating plot for patient: P09
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P09_metrics_and_coefficients.png
# Generating plot for patient: P13
#   Saved plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_P13_metrics_and_coefficients.png
#
# Generating FA-specific diagnostic plots...
# Attempting to generate FA-specific diagnostic plots...
# Could not find/parse SS Loadings block in FA summary file: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/fa_100/model_summary.txt
# Could not generate communality plot: File not found at /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/fa_100/gene_communalities.csv
# LR-Lasso analysis complete!
#
# Results saved to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots
# Files created:
#   - patient_P06_metrics_and_coefficients.png
#   - patient_P13_metrics_and_coefficients.png
#   - patient_P07_metrics_and_coefficients.png
#   - patient_P05_metrics_and_coefficients.png
#   - patient_P02_metrics_and_coefficients.png
#   - patient_P03_metrics_and_coefficients.png
#   - patient_P09_metrics_and_coefficients.png
#   - patient_P04_metrics_and_coefficients.png
#   - patient_P01_metrics_and_coefficients.png

# %% [markdown]
# #### Generate multiVI-based static / selected FA-based dynamic UMAP for selected reg indices

# %%
# Define which patients and alpha indices to analyze
# The keys are patient IDs, and the values are lists of 1-based alpha indices.
patient_indices_to_analyze = {
    "P01": [12, 13, 14],
    "P02": [14, 15, 16],
    "P03": [17], 
    "P04": [11, 12, 13, 14, 15],
    "P05": [9, 10, 11, 12, 13],
    "P06": [9, 10, 11, 12, 13, 14], 
    "P07": [10, 11, 12, 13],
    "P09": [11, 12, 13, 14, 15, 16, 17],
    "P13": [10, 11, 12, 13]
}

# Run the report generation
# This will create and save all the plots in a new directory inside your experiment folder.
analyzer.generate_classification_umap_report(
    experiment_id=experiment_id,
    patient_reg_strength_indices=patient_indices_to_analyze,
    static_umap_rep='X_multivi'  # Specify the obsm key for the static UMAP
)


print("Analysis complete. Check the 'analysis/classification_umaps' directory in your experiment folder.")
# Out:
# --- Generating Classification UMAP Report for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# Processing patient: P01
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P01.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#   Finished dynamic UMAPs for patient P01.
#
# Processing patient: P02
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P02.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#     Index 16: Only 1 active factor. Attempting fallback.
#   Finished dynamic UMAPs for patient P02.
#
# Processing patient: P03
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P03.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#     Index 17: Only 1 active factor. Attempting fallback.
#   Finished dynamic UMAPs for patient P03.
#
# Processing patient: P04
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P04.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#     Index 15: Only 1 active factor. Attempting fallback.
#   Finished dynamic UMAPs for patient P04.
#
# Processing patient: P05
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P05.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#   Finished dynamic UMAPs for patient P05.
#
# Processing patient: P06
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P06.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#     Index 14: Only 1 active factor. Attempting fallback.
#   Finished dynamic UMAPs for patient P06.
#
# Processing patient: P07
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P07.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#   Finished dynamic UMAPs for patient P07.
#
# Processing patient: P09
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P09.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#     Index 16: Only 1 active factor. Attempting fallback.
#     Index 17: Only 1 active factor. Attempting fallback.
#   Finished dynamic UMAPs for patient P09.
#
# Processing patient: P13
#   Generating Static UMAPs based on: 'X_multivi'
#   Finished static UMAPs for patient P13.
#   Generating Dynamic UMAPs based on selected 'fa' factors
#     Index 13: Only 1 active factor. Attempting fallback.
#   Finished dynamic UMAPs for patient P13.
#
# --- Report generation complete. ---
# Analysis complete. Check the 'analysis/classification_umaps' directory in your experiment folder.

# %% [markdown]
# #### Generate JSON files from classification transition analysis between each pair of indicies picked

# %%
print("\n--- Running Classification Transition Analysis (generating the JSON files) ---")

patient_indices_to_analyze = {
    "P01": [12, 13, 14],
    "P02": [14, 15, 16],
    "P03": [17], 
    "P04": [11, 12, 13, 14, 15],
    "P05": [9, 10, 11, 12, 13],
    "P06": [9, 10, 11, 12, 13, 14], 
    "P07": [10, 11, 12, 13],
    "P09": [11, 12, 13, 14, 15, 16, 17],
    "P13": [10, 11, 12, 13]
}

for patient_id, indices in patient_indices_to_analyze.items():
    analyzer.analyze_classification_transitions(
        experiment_id=experiment_id,
        patient_id=patient_id,
        indices_to_check=indices
    )

print("\nTransition analysis complete for all specified patients.")
# Out:
# --- Running Classification Transition Analysis ---
# --- Analyzing Classification Transitions for Patient P01 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 14 to 13...
#   Analyzing transition from index 13 to 12...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P01/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P02 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 16 to 15...
#   Analyzing transition from index 15 to 14...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P02/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P03 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P03/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P04 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 15 to 14...
#   Analyzing transition from index 14 to 13...
#   Analyzing transition from index 13 to 12...
#   Analyzing transition from index 12 to 11...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P04/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P05 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 13 to 12...
#   Analyzing transition from index 12 to 11...
#   Analyzing transition from index 11 to 10...
#   Analyzing transition from index 10 to 9...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P05/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P06 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 14 to 13...
#   Analyzing transition from index 13 to 12...
#   Analyzing transition from index 12 to 11...
#   Analyzing transition from index 11 to 10...
#   Analyzing transition from index 10 to 9...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P06/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P07 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 13 to 12...
#   Analyzing transition from index 12 to 11...
#   Analyzing transition from index 11 to 10...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P07/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P09 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 17 to 16...
#   Analyzing transition from index 16 to 15...
#   Analyzing transition from index 15 to 14...
#   Analyzing transition from index 14 to 13...
#   Analyzing transition from index 13 to 12...
#   Analyzing transition from index 12 to 11...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P09/classification_transitions.json
# --- Analyzing Classification Transitions for Patient P13 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Analyzing transition from index 13 to 12...
#   Analyzing transition from index 12 to 11...
#   Analyzing transition from index 11 to 10...
#
# Successfully saved transition analysis to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/models/classification/P13/classification_transitions.json
#
# Transition analysis complete for all specified patients.

# %%
print("\n--- Generating Detailed Reports for Each Transition ---")

# We can reuse the `patient_indices_to_analyze` dictionary.
for patient_id in patient_indices_to_analyze.keys():
    # This function will print a detailed report to the notebook output.
    # It also prepares the ground for saving more structured results if needed later.
    analyzer.report_on_classification_transitions(
        experiment_id=experiment_id,
        patient_id=patient_id
    )

print("\nFinished generating all transition reports.")
# Out:
# --- Generating Detailed Reports for Each Transition ---
# --- Reporting on Classification Transitions for Patient P01 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# ANALYZING TRANSITION: Index 14 -> 13
# Discovery Factors: ['X_fa_10', 'X_fa_28', 'X_fa_32', 'X_fa_50', 'X_fa_57', 'X_fa_59', 'X_fa_67', 'X_fa_74', 'X_fa_92', 'X_fa_99']
# Cells Flipped to Correct: 84
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_10
#     Successfully ran GSEA for X_fa_10. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_10
#   Running GSEA on factor: X_fa_28
#     Successfully ran GSEA for X_fa_28. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_28
#   Running GSEA on factor: X_fa_32
#     Successfully ran GSEA for X_fa_32. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_32
#   Running GSEA on factor: X_fa_50
#     Successfully ran GSEA for X_fa_50. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_50
#   Running GSEA on factor: X_fa_57
#     Successfully ran GSEA for X_fa_57. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_57
#   Running GSEA on factor: X_fa_59
#     Successfully ran GSEA for X_fa_59. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_59
#   Running GSEA on factor: X_fa_67
#     Successfully ran GSEA for X_fa_67. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_67
#   Running GSEA on factor: X_fa_74
#     Successfully ran GSEA for X_fa_74. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_74
#   Running GSEA on factor: X_fa_92
#     Successfully ran GSEA for X_fa_92. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_92
#   Running GSEA on factor: X_fa_99
#     Successfully ran GSEA for X_fa_99. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_99
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# HSC/MPP2    14
# CLP         13
# NP2         12
# NP1         10
# cDC         10
# MEP-EP       9
# LMPP         5
# ncMono       4
# EBM          3
# MEP-MkP      2
# pDC1         2
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    84.000000
# mean      6.492435
# std       4.303075
# min       0.000000
# 25%       1.460988
# 50%       6.683533
# 75%      10.399087
# max      13.778365
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 13 -> 12
# Discovery Factors: ['X_fa_100', 'X_fa_16', 'X_fa_17', 'X_fa_25', 'X_fa_33', 'X_fa_35', 'X_fa_37', 'X_fa_43', 'X_fa_51', 'X_fa_63', 'X_fa_69', 'X_fa_77', 'X_fa_79', 'X_fa_82', 'X_fa_87', 'X_fa_89', 'X_fa_91', 'X_fa_96']
# Cells Flipped to Correct: 57
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_100
#     Successfully ran GSEA for X_fa_100. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_100
#   Running GSEA on factor: X_fa_16
#     Successfully ran GSEA for X_fa_16. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_16
#   Running GSEA on factor: X_fa_17
#     Successfully ran GSEA for X_fa_17. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_17
#   Running GSEA on factor: X_fa_25
#     Successfully ran GSEA for X_fa_25. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_25
#   Running GSEA on factor: X_fa_33
#     Successfully ran GSEA for X_fa_33. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_33
#   Running GSEA on factor: X_fa_35
#     Successfully ran GSEA for X_fa_35. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_35
#   Running GSEA on factor: X_fa_37
#     Successfully ran GSEA for X_fa_37. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_37
#   Running GSEA on factor: X_fa_43
#     Successfully ran GSEA for X_fa_43. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_43
#   Running GSEA on factor: X_fa_51
#     Successfully ran GSEA for X_fa_51. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_51
#   Running GSEA on factor: X_fa_63
#     Successfully ran GSEA for X_fa_63. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_63
#   Running GSEA on factor: X_fa_69
#     Successfully ran GSEA for X_fa_69. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_69
#   Running GSEA on factor: X_fa_77
#     Successfully ran GSEA for X_fa_77. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_77
#   Running GSEA on factor: X_fa_79
#     Successfully ran GSEA for X_fa_79. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_79
#   Running GSEA on factor: X_fa_82
#     Successfully ran GSEA for X_fa_82. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_82
#   Running GSEA on factor: X_fa_87
#     Successfully ran GSEA for X_fa_87. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_87
#   Running GSEA on factor: X_fa_89
#     Successfully ran GSEA for X_fa_89. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_89
#   Running GSEA on factor: X_fa_91
#     Successfully ran GSEA for X_fa_91. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_91
#   Running GSEA on factor: X_fa_96
#     Successfully ran GSEA for X_fa_96. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_96
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# ncMono      20
# HSC/MPP2     7
# NP2          7
# NP1          6
# cDC          5
# HSC/MPP1     4
# MEP-MkP      3
# EBM          2
# LMPP         2
# pDC1         1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    57.000000
# mean      7.299380
# std       5.094421
# min       0.000082
# 25%       1.232444
# 50%       9.247008
# 75%      11.923098
# max      12.462564
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# Transition reporting complete.
# --- Reporting on Classification Transitions for Patient P02 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# ANALYZING TRANSITION: Index 16 -> 15
# Discovery Factors: ['X_fa_10', 'X_fa_81', 'X_fa_95', 'X_fa_96']
# Cells Flipped to Correct: 284
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_10
#     Successfully ran GSEA for X_fa_10. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_10
#   Running GSEA on factor: X_fa_81
#     Successfully ran GSEA for X_fa_81. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_81
#   Running GSEA on factor: X_fa_95
#     Successfully ran GSEA for X_fa_95. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_95
#   Running GSEA on factor: X_fa_96
#     Successfully ran GSEA for X_fa_96. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_96
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# CLP         228
# NP2          13
# MEP-EP       11
# NP1          10
# HSC/MPP2      7
# cDC           6
# LMPP          4
# HSC/MPP1      2
# EBM           1
# MEP-MkP       1
# pDC1          1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    284.000000
# mean       6.536402
# std        2.124308
# min        0.028269
# 25%        5.966463
# 50%        6.564608
# 75%        7.045655
# max       13.778401
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 15 -> 14
# Discovery Factors: ['X_fa_14', 'X_fa_74', 'X_fa_79', 'X_fa_80', 'X_fa_83', 'X_fa_84', 'X_fa_85', 'X_fa_89', 'X_fa_91']
# Cells Flipped to Correct: 61
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_14
#     Successfully ran GSEA for X_fa_14. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_14
#   Running GSEA on factor: X_fa_74
#     Successfully ran GSEA for X_fa_74. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_74
#   Running GSEA on factor: X_fa_79
#     Successfully ran GSEA for X_fa_79. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_79
#   Running GSEA on factor: X_fa_80
#     Successfully ran GSEA for X_fa_80. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_80
#   Running GSEA on factor: X_fa_83
#     Successfully ran GSEA for X_fa_83. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_83
#   Running GSEA on factor: X_fa_84
#     Successfully ran GSEA for X_fa_84. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_84
#   Running GSEA on factor: X_fa_85
#     Successfully ran GSEA for X_fa_85. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_85
#   Running GSEA on factor: X_fa_89
#     Successfully ran GSEA for X_fa_89. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_89
#   Running GSEA on factor: X_fa_91
#     Successfully ran GSEA for X_fa_91. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_91
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# CLP         19
# HSC/MPP1    10
# NP2         10
# EBM          6
# NP1          6
# HSC/MPP2     4
# LMPP         4
# cDC          1
# pDC2         1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    61.000000
# mean      4.695374
# std       3.152832
# min       0.000004
# 25%       1.241621
# 50%       5.735525
# 75%       6.683612
# max      13.438679
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# Transition reporting complete.
# --- Reporting on Classification Transitions for Patient P03 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# Transition reporting complete.
# --- Reporting on Classification Transitions for Patient P04 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# ANALYZING TRANSITION: Index 15 -> 14
# Discovery Factors: ['X_fa_19', 'X_fa_46', 'X_fa_47', 'X_fa_71']
# Cells Flipped to Correct: 71
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_19
#     Successfully ran GSEA for X_fa_19. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_19
#   Running GSEA on factor: X_fa_46
#     Successfully ran GSEA for X_fa_46. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_46
#   Running GSEA on factor: X_fa_47
#     Successfully ran GSEA for X_fa_47. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_47
#   Running GSEA on factor: X_fa_71
#     Successfully ran GSEA for X_fa_71. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_71
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# CLP         20
# MEP-EP      18
# MEP-MkP      9
# HSC/MPP1     8
# HSC/MPP2     6
# pDC1         4
# NP1          3
# LMPP         2
# EBM          1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    71.000000
# mean      6.515461
# std       4.078820
# min       0.000004
# 25%       3.978701
# 50%       7.045640
# 75%       9.976606
# max      13.340512
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 14 -> 13
# Discovery Factors: ['X_fa_11', 'X_fa_16', 'X_fa_20', 'X_fa_25', 'X_fa_30', 'X_fa_32', 'X_fa_61', 'X_fa_73', 'X_fa_84', 'X_fa_90', 'X_fa_95']
# Cells Flipped to Correct: 49
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_11
#     Successfully ran GSEA for X_fa_11. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_11
#   Running GSEA on factor: X_fa_16
#     Successfully ran GSEA for X_fa_16. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_16
#   Running GSEA on factor: X_fa_20
#     Successfully ran GSEA for X_fa_20. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_20
#   Running GSEA on factor: X_fa_25
#     Successfully ran GSEA for X_fa_25. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_25
#   Running GSEA on factor: X_fa_30
#     Successfully ran GSEA for X_fa_30. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_30
#   Running GSEA on factor: X_fa_32
#     Successfully ran GSEA for X_fa_32. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_32
#   Running GSEA on factor: X_fa_61
#     Successfully ran GSEA for X_fa_61. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_61
#   Running GSEA on factor: X_fa_73
#     Successfully ran GSEA for X_fa_73. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_73
#   Running GSEA on factor: X_fa_84
#     Successfully ran GSEA for X_fa_84. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_84
#   Running GSEA on factor: X_fa_90
#     Successfully ran GSEA for X_fa_90. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_90
#   Running GSEA on factor: X_fa_95
#     Successfully ran GSEA for X_fa_95. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_95
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# CLP         17
# EBM         10
# HSC/MPP1     4
# cDC          4
# HSC/MPP2     3
# MEP-MkP      3
# pDC1         3
# MEP-EP       2
# NP1          2
# LMPP         1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    49.000000
# mean      6.098857
# std       3.076877
# min       0.000004
# 25%       5.891542
# 50%       6.683586
# 75%       7.045660
# max      12.659608
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 13 -> 12
# Discovery Factors: ['X_fa_100', 'X_fa_28', 'X_fa_33', 'X_fa_35', 'X_fa_42', 'X_fa_45', 'X_fa_5', 'X_fa_51', 'X_fa_57', 'X_fa_58', 'X_fa_72', 'X_fa_81', 'X_fa_86', 'X_fa_89', 'X_fa_99']
# Cells Flipped to Correct: 36
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_100
#     Successfully ran GSEA for X_fa_100. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_100
#   Running GSEA on factor: X_fa_28
#     Successfully ran GSEA for X_fa_28. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_28
#   Running GSEA on factor: X_fa_33
#     Successfully ran GSEA for X_fa_33. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_33
#   Running GSEA on factor: X_fa_35
#     Successfully ran GSEA for X_fa_35. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_35
#   Running GSEA on factor: X_fa_42
#     Successfully ran GSEA for X_fa_42. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_42
#   Running GSEA on factor: X_fa_45
#     Successfully ran GSEA for X_fa_45. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_45
#   Running GSEA on factor: X_fa_5
#     Successfully ran GSEA for X_fa_5. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_5
#   Running GSEA on factor: X_fa_51
#     Successfully ran GSEA for X_fa_51. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_51
#   Running GSEA on factor: X_fa_57
#     Successfully ran GSEA for X_fa_57. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_57
#   Running GSEA on factor: X_fa_58
#     Successfully ran GSEA for X_fa_58. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_58
#   Running GSEA on factor: X_fa_72
#     Successfully ran GSEA for X_fa_72. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_72
#   Running GSEA on factor: X_fa_81
#     Successfully ran GSEA for X_fa_81. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_81
#   Running GSEA on factor: X_fa_86
#     Successfully ran GSEA for X_fa_86. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_86
#   Running GSEA on factor: X_fa_89
#     Successfully ran GSEA for X_fa_89. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_89
#   Running GSEA on factor: X_fa_99
#     Successfully ran GSEA for X_fa_99. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_99
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# HSC/MPP1    7
# CLP         5
# pDC1        5
# MEP-MkP     4
# MEP-EP      3
# NP2         3
# cDC         3
# EBM         2
# LMPP        2
# HSC/MPP2    1
# NP1         1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    36.000000
# mean      5.728652
# std       3.994963
# min       0.000004
# 25%       0.069209
# 50%       6.683592
# 75%       9.000001
# max      12.008381
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 12 -> 11
# Discovery Factors: ['X_fa_13', 'X_fa_14', 'X_fa_18', 'X_fa_32', 'X_fa_37', 'X_fa_40', 'X_fa_50', 'X_fa_54', 'X_fa_56', 'X_fa_59', 'X_fa_60', 'X_fa_64', 'X_fa_66', 'X_fa_76', 'X_fa_78', 'X_fa_79', 'X_fa_80', 'X_fa_83', 'X_fa_85', 'X_fa_91', 'X_fa_92', 'X_fa_98']
# Cells Flipped to Correct: 41
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_13
#     Successfully ran GSEA for X_fa_13. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_13
#   Running GSEA on factor: X_fa_14
#     Successfully ran GSEA for X_fa_14. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_14
#   Running GSEA on factor: X_fa_18
#     Successfully ran GSEA for X_fa_18. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_18
#   Running GSEA on factor: X_fa_32
#     Successfully ran GSEA for X_fa_32. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_32
#   Running GSEA on factor: X_fa_37
#     Successfully ran GSEA for X_fa_37. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_37
#   Running GSEA on factor: X_fa_40
#     Successfully ran GSEA for X_fa_40. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_40
#   Running GSEA on factor: X_fa_50
#     Successfully ran GSEA for X_fa_50. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_50
#   Running GSEA on factor: X_fa_54
#     Successfully ran GSEA for X_fa_54. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_54
#   Running GSEA on factor: X_fa_56
#     Successfully ran GSEA for X_fa_56. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_56
#   Running GSEA on factor: X_fa_59
#     Successfully ran GSEA for X_fa_59. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_59
#   Running GSEA on factor: X_fa_60
#     Successfully ran GSEA for X_fa_60. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_60
#   Running GSEA on factor: X_fa_64
#     Successfully ran GSEA for X_fa_64. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_64
#   Running GSEA on factor: X_fa_66
#     Successfully ran GSEA for X_fa_66. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_66
#   Running GSEA on factor: X_fa_76
#     Successfully ran GSEA for X_fa_76. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_76
#   Running GSEA on factor: X_fa_78
#     Successfully ran GSEA for X_fa_78. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_78
#   Running GSEA on factor: X_fa_79
#     Successfully ran GSEA for X_fa_79. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_79
#   Running GSEA on factor: X_fa_80
#     Successfully ran GSEA for X_fa_80. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_80
#   Running GSEA on factor: X_fa_83
#     Successfully ran GSEA for X_fa_83. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_83
#   Running GSEA on factor: X_fa_85
#     Successfully ran GSEA for X_fa_85. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_85
#   Running GSEA on factor: X_fa_91
#     Successfully ran GSEA for X_fa_91. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_91
#   Running GSEA on factor: X_fa_92
#     Successfully ran GSEA for X_fa_92. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_92
#   Running GSEA on factor: X_fa_98
#     Successfully ran GSEA for X_fa_98. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_98
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# cDC         17
# MEP-EP       7
# MEP-MkP      4
# pDC1         4
# CLP          2
# EBM          2
# HSC/MPP1     2
# HSC/MPP2     1
# NP2          1
# pDC2         1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    41.000000
# mean      9.596673
# std       3.171061
# min       0.069198
# 25%       9.046776
# 50%      10.422031
# 75%      11.538492
# max      14.028843
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# Transition reporting complete.
# --- Reporting on Classification Transitions for Patient P05 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# ANALYZING TRANSITION: Index 13 -> 12
# Discovery Factors: ['X_fa_43', 'X_fa_81']
# Cells Flipped to Correct: 6
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_43
#     Successfully ran GSEA for X_fa_43. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_43
#   Running GSEA on factor: X_fa_81
#     Successfully ran GSEA for X_fa_81. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_81
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# EBM     5
# LMPP    1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    6.000000
# mean     5.759509
# std      2.344559
# min      0.975560
# 25%      6.683587
# 50%      6.683604
# 75%      6.683609
# max      6.847093
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 12 -> 11
# Discovery Factors: ['X_fa_57', 'X_fa_69', 'X_fa_71', 'X_fa_92', 'X_fa_93']
# Cells Flipped to Correct: 4
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_57
#     Successfully ran GSEA for X_fa_57. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_57
#   Running GSEA on factor: X_fa_69
#     Successfully ran GSEA for X_fa_69. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_69
#   Running GSEA on factor: X_fa_71
#     Successfully ran GSEA for X_fa_71. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_71
#   Running GSEA on factor: X_fa_92
#     Successfully ran GSEA for X_fa_92. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_92
#   Running GSEA on factor: X_fa_93
#     Successfully ran GSEA for X_fa_93. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_93
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# LMPP        3
# HSC/MPP1    1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    4.000000
# mean     1.115087
# std      1.046853
# min      0.199714
# 25%      0.579986
# 50%      0.822479
# 75%      1.357580
# max      2.615676
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 11 -> 10
# Discovery Factors: ['X_fa_29', 'X_fa_45', 'X_fa_61', 'X_fa_88', 'X_fa_90', 'X_fa_95', 'X_fa_96', 'X_fa_97']
# Cells Flipped to Correct: 3
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_29
#     Successfully ran GSEA for X_fa_29. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_29
#   Running GSEA on factor: X_fa_45
#     Successfully ran GSEA for X_fa_45. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_45
#   Running GSEA on factor: X_fa_61
#     Successfully ran GSEA for X_fa_61. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_61
#   Running GSEA on factor: X_fa_88
#     Successfully ran GSEA for X_fa_88. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_88
#   Running GSEA on factor: X_fa_90
#     Successfully ran GSEA for X_fa_90. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_90
#   Running GSEA on factor: X_fa_95
#     Successfully ran GSEA for X_fa_95. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_95
#   Running GSEA on factor: X_fa_96
#     Successfully ran GSEA for X_fa_96. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_96
#   Running GSEA on factor: X_fa_97
#     Successfully ran GSEA for X_fa_97. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_97
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# HSC/MPP1    2
# LMPP        1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    3.000000
# mean     0.046067
# std      0.039893
# min      0.000003
# 25%      0.034504
# 50%      0.069004
# 75%      0.069100
# max      0.069195
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 10 -> 9
# Discovery Factors: ['X_fa_20', 'X_fa_22', 'X_fa_35', 'X_fa_47', 'X_fa_62', 'X_fa_65', 'X_fa_77', 'X_fa_85', 'X_fa_89']
# Cells Flipped to Correct: 3
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_20
#     Successfully ran GSEA for X_fa_20. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_20
#   Running GSEA on factor: X_fa_22
#     Successfully ran GSEA for X_fa_22. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_22
#   Running GSEA on factor: X_fa_35
#     Successfully ran GSEA for X_fa_35. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_35
#   Running GSEA on factor: X_fa_47
#     Successfully ran GSEA for X_fa_47. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_47
#   Running GSEA on factor: X_fa_62
#     Successfully ran GSEA for X_fa_62. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_62
#   Running GSEA on factor: X_fa_65
#     Successfully ran GSEA for X_fa_65. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_65
#   Running GSEA on factor: X_fa_77
#     Successfully ran GSEA for X_fa_77. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_77
#   Running GSEA on factor: X_fa_85
#     Successfully ran GSEA for X_fa_85. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_85
#   Running GSEA on factor: X_fa_89
#     Successfully ran GSEA for X_fa_89. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_89
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# HSC/MPP1    2
# LMPP        1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    3.000000
# mean     0.046114
# std      0.039933
# min      0.000003
# 25%      0.034586
# 50%      0.069169
# 75%      0.069169
# max      0.069169
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# Transition reporting complete.
# --- Reporting on Classification Transitions for Patient P06 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# ANALYZING TRANSITION: Index 14 -> 13
# Discovery Factors: ['X_fa_12', 'X_fa_29', 'X_fa_33', 'X_fa_52', 'X_fa_59', 'X_fa_61', 'X_fa_63', 'X_fa_71']
# Cells Flipped to Correct: 28
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_12
#     Successfully ran GSEA for X_fa_12. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_12
#   Running GSEA on factor: X_fa_29
#     Successfully ran GSEA for X_fa_29. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_29
#   Running GSEA on factor: X_fa_33
#     Successfully ran GSEA for X_fa_33. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_33
#   Running GSEA on factor: X_fa_52
#     Successfully ran GSEA for X_fa_52. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_52
#   Running GSEA on factor: X_fa_59
#     Successfully ran GSEA for X_fa_59. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_59
#   Running GSEA on factor: X_fa_61
#     Successfully ran GSEA for X_fa_61. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_61
#   Running GSEA on factor: X_fa_63
#     Successfully ran GSEA for X_fa_63. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_63
#   Running GSEA on factor: X_fa_71
#     Successfully ran GSEA for X_fa_71. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_71
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# cDC         7
# pDC1        7
# LMPP        6
# MEP-EP      4
# CLP         2
# EBM         1
# HSC/MPP2    1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    28.000000
# mean      8.535438
# std       4.225804
# min       0.000647
# 25%       5.587926
# 50%       9.734912
# 75%      12.061399
# max      13.768615
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 13 -> 12
# Discovery Factors: ['X_fa_100', 'X_fa_11', 'X_fa_23', 'X_fa_28', 'X_fa_31', 'X_fa_41', 'X_fa_42', 'X_fa_47', 'X_fa_53', 'X_fa_57', 'X_fa_6', 'X_fa_60', 'X_fa_69', 'X_fa_74', 'X_fa_84', 'X_fa_89']
# Cells Flipped to Correct: 29
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_100
#     Successfully ran GSEA for X_fa_100. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_100
#   Running GSEA on factor: X_fa_11
#     Successfully ran GSEA for X_fa_11. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_11
#   Running GSEA on factor: X_fa_23
#     Successfully ran GSEA for X_fa_23. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_23
#   Running GSEA on factor: X_fa_28
#     Successfully ran GSEA for X_fa_28. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_28
#   Running GSEA on factor: X_fa_31
#     Successfully ran GSEA for X_fa_31. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_31
#   Running GSEA on factor: X_fa_41
#     Successfully ran GSEA for X_fa_41. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_41
#   Running GSEA on factor: X_fa_42
#     Successfully ran GSEA for X_fa_42. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_42
#   Running GSEA on factor: X_fa_47
#     Successfully ran GSEA for X_fa_47. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_47
#   Running GSEA on factor: X_fa_53
#     Successfully ran GSEA for X_fa_53. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_53
#   Running GSEA on factor: X_fa_57
#     Successfully ran GSEA for X_fa_57. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_57
#   Running GSEA on factor: X_fa_6
#     Successfully ran GSEA for X_fa_6. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_6
#   Running GSEA on factor: X_fa_60
#     Successfully ran GSEA for X_fa_60. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_60
#   Running GSEA on factor: X_fa_69
#     Successfully ran GSEA for X_fa_69. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_69
#   Running GSEA on factor: X_fa_74
#     Successfully ran GSEA for X_fa_74. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_74
#   Running GSEA on factor: X_fa_84
# ...
#     Successfully ran GSEA for X_fa_98. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_98
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# LMPP    3
# NP2     2
# CLP     1
# cDC     1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count     7.000000
# mean      5.510642
# std       4.181243
# min       0.729974
# 25%       2.332567
# 50%       4.381803
# 75%       8.703812
# max      11.389960
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 13 -> 12
# Discovery Factors: ['X_fa_12', 'X_fa_19', 'X_fa_21', 'X_fa_43', 'X_fa_51', 'X_fa_52', 'X_fa_59', 'X_fa_61', 'X_fa_73', 'X_fa_78', 'X_fa_79', 'X_fa_89', 'X_fa_94', 'X_fa_99']
# Cells Flipped to Correct: 9
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_12
#     Successfully ran GSEA for X_fa_12. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_12
#   Running GSEA on factor: X_fa_19
#     Successfully ran GSEA for X_fa_19. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_19
#   Running GSEA on factor: X_fa_21
#     Successfully ran GSEA for X_fa_21. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_21
#   Running GSEA on factor: X_fa_43
#     Successfully ran GSEA for X_fa_43. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_43
#   Running GSEA on factor: X_fa_51
#     Successfully ran GSEA for X_fa_51. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_51
#   Running GSEA on factor: X_fa_52
#     Successfully ran GSEA for X_fa_52. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_52
#   Running GSEA on factor: X_fa_59
#     Successfully ran GSEA for X_fa_59. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_59
#   Running GSEA on factor: X_fa_61
#     Successfully ran GSEA for X_fa_61. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_61
#   Running GSEA on factor: X_fa_73
#     Successfully ran GSEA for X_fa_73. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_73
#   Running GSEA on factor: X_fa_78
#     Successfully ran GSEA for X_fa_78. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_78
#   Running GSEA on factor: X_fa_79
#     Successfully ran GSEA for X_fa_79. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_79
#   Running GSEA on factor: X_fa_89
#     Successfully ran GSEA for X_fa_89. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_89
#   Running GSEA on factor: X_fa_94
#     Successfully ran GSEA for X_fa_94. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_94
#   Running GSEA on factor: X_fa_99
#     Successfully ran GSEA for X_fa_99. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_99
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# cDC        4
# CLP        1
# EBM        1
# LMPP       1
# MEP-MkP    1
# NP1        1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count     9.000000
# mean      8.552920
# std       3.076627
# min       4.590727
# 25%       5.732516
# 50%       8.254779
# 75%      11.538459
# max      11.847204
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 12 -> 11
# Discovery Factors: ['X_fa_1', 'X_fa_100', 'X_fa_16', 'X_fa_20', 'X_fa_31', 'X_fa_32', 'X_fa_40', 'X_fa_44', 'X_fa_82', 'X_fa_83', 'X_fa_88', 'X_fa_90', 'X_fa_92', 'X_fa_96']
# Cells Flipped to Correct: 9
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_1
#     Successfully ran GSEA for X_fa_1. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_1
#   Running GSEA on factor: X_fa_100
#     Successfully ran GSEA for X_fa_100. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_100
#   Running GSEA on factor: X_fa_16
#     Successfully ran GSEA for X_fa_16. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_16
#   Running GSEA on factor: X_fa_20
#     Successfully ran GSEA for X_fa_20. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_20
#   Running GSEA on factor: X_fa_31
#     Successfully ran GSEA for X_fa_31. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_31
#   Running GSEA on factor: X_fa_32
#     Successfully ran GSEA for X_fa_32. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_32
#   Running GSEA on factor: X_fa_40
#     Successfully ran GSEA for X_fa_40. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_40
#   Running GSEA on factor: X_fa_44
#     Successfully ran GSEA for X_fa_44. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_44
#   Running GSEA on factor: X_fa_82
#     Successfully ran GSEA for X_fa_82. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_82
#   Running GSEA on factor: X_fa_83
#     Successfully ran GSEA for X_fa_83. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_83
#   Running GSEA on factor: X_fa_88
#     Successfully ran GSEA for X_fa_88. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_88
#   Running GSEA on factor: X_fa_90
#     Successfully ran GSEA for X_fa_90. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_90
#   Running GSEA on factor: X_fa_92
#     Successfully ran GSEA for X_fa_92. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_92
#   Running GSEA on factor: X_fa_96
#     Successfully ran GSEA for X_fa_96. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_96
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# EBM         2
# LMPP        2
# CLP         1
# HSC/MPP2    1
# MEP-EP      1
# cDC         1
# ncMono      1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count     9.000000
# mean      6.603604
# std       4.944928
# min       0.000647
# 25%       1.695254
# 50%       6.683590
# 75%      11.227042
# max      13.768615
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# Transition reporting complete.
# --- Reporting on Classification Transitions for Patient P13 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# ==================================================
# ANALYZING TRANSITION: Index 13 -> 12
# Discovery Factors: ['X_fa_20', 'X_fa_95']
# Cells Flipped to Correct: 6
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_20
#     Successfully ran GSEA for X_fa_20. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_20
#   Running GSEA on factor: X_fa_95
#     Successfully ran GSEA for X_fa_95. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_95
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# EBM        3
# MEP-MkP    2
# LMPP       1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    6.000000
# mean     6.597318
# std      2.954515
# min      1.063259
# 25%      6.683594
# 50%      6.778736
# 75%      8.564529
# max      9.151501
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 12 -> 11
# Discovery Factors: ['X_fa_17', 'X_fa_45', 'X_fa_61', 'X_fa_63', 'X_fa_69', 'X_fa_71', 'X_fa_72', 'X_fa_78', 'X_fa_85', 'X_fa_88', 'X_fa_92']
# Cells Flipped to Correct: 10
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_17
#     Successfully ran GSEA for X_fa_17. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_17
#   Running GSEA on factor: X_fa_45
#     Successfully ran GSEA for X_fa_45. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_45
#   Running GSEA on factor: X_fa_61
#     Successfully ran GSEA for X_fa_61. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_61
#   Running GSEA on factor: X_fa_63
#     Successfully ran GSEA for X_fa_63. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_63
#   Running GSEA on factor: X_fa_69
#     Successfully ran GSEA for X_fa_69. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_69
#   Running GSEA on factor: X_fa_71
#     Successfully ran GSEA for X_fa_71. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_71
#   Running GSEA on factor: X_fa_72
#     Successfully ran GSEA for X_fa_72. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_72
#   Running GSEA on factor: X_fa_78
#     Successfully ran GSEA for X_fa_78. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_78
#   Running GSEA on factor: X_fa_85
#     Successfully ran GSEA for X_fa_85. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_85
#   Running GSEA on factor: X_fa_88
#     Successfully ran GSEA for X_fa_88. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_88
#   Running GSEA on factor: X_fa_92
#     Successfully ran GSEA for X_fa_92. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_92
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# HSC/MPP1    6
# EBM         3
# LMPP        1
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    10.000000
# mean      2.729925
# std       3.233034
# min       0.152625
# 25%       0.206067
# 50%       0.309930
# 75%       6.475338
# max       6.683605
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# ANALYZING TRANSITION: Index 11 -> 10
# Discovery Factors: ['X_fa_33', 'X_fa_38', 'X_fa_42']
# Cells Flipped to Correct: 8
#
#   Running GSEA on discovery factors...
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_33
#     Successfully ran GSEA for X_fa_33. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_33
#   Running GSEA on factor: X_fa_38
#     Successfully ran GSEA for X_fa_38. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_38
#   Running GSEA on factor: X_fa_42
#     Successfully ran GSEA for X_fa_42. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_42
#
#   Cell Type Composition of Flipped Cells:
# predicted.annotation
# LMPP        5
# HSC/MPP1    3
# Name: count, dtype: int64
#
#   Pseudotime Distribution of Flipped Cells:
# count    8.000000
# mean     1.050461
# std      1.008439
# min      0.069220
# 25%      0.583293
# 50%      0.982440
# 75%      1.045723
# max      3.358456
# Name: predicted.pseudotime, dtype: float64
#
# ==================================================
# Transition reporting complete.
#
# Finished generating all transition reports.

# %% [markdown]
# Test on low variance, high importance factors' GSEA strategy [1. on the original factor; 2. on the predictive loading]

# %%
patient_to_test = 'P05'
low_variance_factor = 'X_fa_63'
important_alpha_idx = 13

# --- A) Run standard GSEA on the low-variance factor ---
print(f"\n--- Running UNSUPERVISED GSEA on {low_variance_factor} ---")
analyzer.run_gsea_on_factors(
    experiment_id=experiment_id,
    factor_names=[low_variance_factor]
)

# --- B) Run SUPERVISED GSEA on the Predictive Loading ---
print(f"\n--- Running SUPERVISED GSEA for {patient_to_test} at alpha index {important_alpha_idx} ---")
analyzer.run_gsea_on_predictive_loading(
    experiment_id=experiment_id,
    patient_id=patient_to_test,
    alpha_index=important_alpha_idx
)

print("\n--- Comparison Complete ---")
print(f"1. Check the GSEA plot for '{low_variance_factor}' in 'analysis/factor_interpretation/gsea_on_top_DR_factors/'")
print(f"2. Check the GSEA plot in 'analysis/supervised_gsea/{patient_to_test}/alpha_idx_{important_alpha_idx}/'")
print("3. Compare the NES scores and p-values. Pathways should be more significant in the supervised result.")
# Out:
# --- Running UNSUPERVISED GSEA on X_fa_63 ---
# --- Running GSEA on Top Unsupervised Factors for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Running GSEA on factor: X_fa_63
#     Successfully ran GSEA for X_fa_63. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/factor_interpretation/gsea_on_top_DR_factors/X_fa_63
#
# --- Running SUPERVISED GSEA for P05 at alpha index 13 ---
# --- Running GSEA on Predictive Loading for Patient P05 at alpha index 13 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Calculating predictive loading vector...
#   Running GSEA...
#   Successfully ran supervised GSEA. Results in /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/supervised_gsea/P05/alpha_idx_13
#
# --- Comparison Complete ---
# 1. Check the GSEA plot for 'X_fa_63' in 'analysis/factor_interpretation/gsea_on_top_DR_factors/'
# 2. Check the GSEA plot in 'analysis/supervised_gsea/P05/alpha_idx_13/'
# 3. Compare the NES scores and p-values. Pathways should be more significant in the supervised result.

# %% [markdown]
# #### Overall across patient MRD heterogeneity

# %%
experiment_id = "20250714_205422_fa_100_random_6dbbde08" # Replace with your actual experiment ID

# Generate the accuracy vs. number of factors plot
analyzer.plot_accuracy_vs_n_factors_summary(
    experiment_id=experiment_id,
    metric='overall_accuracy'  # You can change this to 'roc_auc', 'mal_accuracy', etc.
)

# You can also generate one for ROC AUC
analyzer.plot_accuracy_vs_n_factors_summary(
    experiment_id=experiment_id,
    metric='roc_auc'
)
# Out:
# --- Generating Accuracy vs. Number of Factors Summary for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved summary plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/summary_accuracy_vs_n_factors_overall_accuracy.png
# --- Generating Accuracy vs. Number of Factors Summary for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved summary plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/summary_accuracy_vs_n_factors_roc_auc.png

# %%
# You can also generate one for ROC AUC
analyzer.plot_accuracy_vs_n_factors_summary(
    experiment_id=experiment_id,
    metric='mal_accuracy'
)
# Out:
# --- Generating Accuracy vs. Number of Factors Summary for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved summary plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/summary_accuracy_vs_n_factors_mal_accuracy.png

# %%
# Generate the bar plot for factors needed for good performance
analyzer.plot_factors_for_good_accuracy_summary(
    experiment_id=experiment_id,
    margin=0.0 # Default: accuracy just needs to be > trivial accuracy
)

'''
# Example with a stricter margin
analyzer.plot_factors_for_good_accuracy_summary(
    experiment_id=experiment_id,
    margin=0.05 # Accuracy needs to be at least 5% > trivial accuracy
)
'''
# Out:
# --- Generating 'Factors for Good Accuracy' Summary for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved summary bar plot to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/summary_factors_for_good_accuracy.png
# '\n# Example with a stricter margin\nanalyzer.plot_factors_for_good_accuracy_summary(\n    experiment_id=experiment_id,\n    margin=0.05 # Accuracy needs to be at least 5% > trivial accuracy\n)\n'

# %%
experiment_id = "20250714_205422_fa_100_random_6dbbde08"
analyzer.plot_patient_cluster_w_factor_coefs_at_best_reg_strength(
    experiment_id=experiment_id
)
# Out:
# --- Clustering Patients by Factor Coefficients for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Saved patient clustering heatmap to /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_factor_coefficient_clustermap.png

# %% [markdown]
# #### Visualize YH's DEG genes in factor space

# %%
experiment_id = "20250714_205422_fa_100_random_6dbbde08" # Replace with your actual experiment ID
genes_to_visualize = ['PTH2R', 'GNG11', 'SH2D1A', 'DLGAP2', 'ST3GAL1']

# Generate the gene visualization report
analyzer.visualize_gene_in_factor_space(
    experiment_id=experiment_id,
    genes_of_interest=genes_to_visualize
)
# Out:
# --- Visualizing Genes in Factor Space for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#
# --- Communality Scores ---
#   - PTH2R: Not found in the model's gene list.
#   - GNG11: Not found in the model's gene list.
#   - SH2D1A: Not found in the model's gene list.
#   - DLGAP2: 0.9390
#   - ST3GAL1: Not found in the model's gene list.
#
# Saved gene loading heatmap to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/gene_loadings_heatmap_DLGAP2.png

# %% [markdown]
# ---
# ### Deeper Dive into Model Structure
#
# To better understand patient heterogeneity, we will now move beyond looking at factor coefficients and analyze the model in two new ways:
#
# 1.  **Factor Similarity Analysis:** We will check if the model has learned redundant factors. If different factors are built from the same genes, they are biologically equivalent. We will analyze this with two methods: direct correlation of factor loading vectors and the overlap of their top contributing genes.
# 2.  **Patient Clustering in Gene Space:** To get a more biologically meaningful grouping of patients, we will calculate a "predictive gene signature" for each patient (`signature = Loadings @ Coefficients`). We will then cluster the patients based on these gene-level signatures. This should reveal groups of patients who rely on similar biological programs for classification, even if they use different combinations of factors to get there.
#
# ---

# %%
# --- Set the experiment ID ---
experiment_id = "20250714_205422_fa_100_random_6dbbde08" # Replace with your actual experiment ID

# Analyze the similarity between the learned factors
analyzer.analyze_factor_similarity(
    experiment_id=experiment_id,
    top_n_genes=200 # Number of top genes to use for the overlap calculation
)
# Out:
# --- Analyzing Factor Similarity for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
#   Calculating factor-factor correlation...
#   Saved factor correlation heatmap to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/factor_loading_correlation_heatmap.png
#   Calculating top 200 gene overlap (Jaccard Index)...
#   Saved gene overlap heatmap to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/unsupervised_dr_analysis/factor_top_gene_overlap_heatmap.png

# %%
# --- Use the same experiment ID ---
experiment_id = "20250714_205422_fa_100_random_6dbbde08" # Replace with your actual experiment ID

# Cluster patients based on their "predictive loading" in gene space
analyzer.plot_patient_cluster_in_gene_space(
    experiment_id=experiment_id,
    n_top_genes=100 # Use the top 100 most variable genes for the heatmap
)
# Out:
# --- Clustering Patients in Gene Space for Experiment: 20250714_205422_fa_100_random_6dbbde08 ---
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Loading experiment from: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08
# Clustering patients based on the top 100 most variable signature genes.
# Saved gene-space clustering heatmap to: /home/minhang/mds_project/sc_classification/experiments/20250714_205422_fa_100_random_6dbbde08/analysis/summary_plots/patient_gene_space_clustermap.png
